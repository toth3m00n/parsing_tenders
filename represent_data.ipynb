# %%
import pandas as pd
from main import app

# %%
app()

# %%
pd.read_csv("tenders.csv", delimiter=',')
# Out:
#       number                                        description date_start  \
# 0   79063508                          Поставка (кофры для БПЛА)   21.10.24
# 1   79064209  Поставка запасных частей, моторного масла, фил...   21.10.24
# 2   79062125  Оказание услуг по организации служебных команд...   21.10.24
# 3   79061098  Оказание услуг по поисково – спасательному обе...   21.10.24
# 4   79058900  Поставка беспилотных летательных аппаратов (др...   21.10.24
# 5   79058073                                  Поставка керосина   21.10.24
# 6   79055274  Оказание услуг по поисково – спасательному обе...   21.10.24
# 7   79055276  Оказание услуг по поисково – спасательному обе...   21.10.24
# 8   79056770                                 Поставка игрушек 2   21.10.24
# 9   79048206  Оказание услуг по перевозке пенсионеров воздуш...   21.10.24
# 10  79052862  Поставка топлива для реактивных двигателей для...   21.10.24
# ...
